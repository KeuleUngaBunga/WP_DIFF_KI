# %%
# Run this line in Colab to install the package if it is
# not already installed.
# !pip install git+https://github.com/openai/glide-text2im
# Out:
# Collecting git+https://github.com/openai/glide-text2im
#   Cloning https://github.com/openai/glide-text2im to /tmp/pip-req-build-wyibbiaq
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/glide-text2im /tmp/pip-req-build-wyibbiaq
#   Resolved https://github.com/openai/glide-text2im to commit 69b530740eb6cef69442d6180579ef5ba9ef063e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: Pillow in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from glide-text2im==0.0.0) (12.0.0)
# Requirement already satisfied: attrs in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from glide-text2im==0.0.0) (25.4.0)
# Requirement already satisfied: torch in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from glide-text2im==0.0.0) (2.9.1)
# Requirement already satisfied: filelock in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from glide-text2im==0.0.0) (3.20.0)
# Requirement already satisfied: requests in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from glide-text2im==0.0.0) (2.32.5)
# Requirement already satisfied: tqdm in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from glide-text2im==0.0.0) (4.67.1)
# Requirement already satisfied: ftfy in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from glide-text2im==0.0.0) (6.3.1)
# Requirement already satisfied: regex in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from glide-text2im==0.0.0) (2025.11.3)
# Requirement already satisfied: numpy in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from glide-text2im==0.0.0) (2.3.5)
# Requirement already satisfied: wcwidth in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from ftfy->glide-text2im==0.0.0) (0.2.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from requests->glide-text2im==0.0.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from requests->glide-text2im==0.0.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from requests->glide-text2im==0.0.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from requests->glide-text2im==0.0.0) (2025.11.12)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (4.15.0)
# Requirement already satisfied: setuptools in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (3.5)
# Requirement already satisfied: jinja2 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from torch->glide-text2im==0.0.0) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from sympy>=1.13.3->torch->glide-text2im==0.0.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fiona/anaconda3/envs/GAI2/lib/python3.12/site-packages (from jinja2->torch->glide-text2im==0.0.0) (3.0.2)

# %%
from PIL import Image
from IPython.display import display
import torch as th

from glide_text2im.download import load_checkpoint
from glide_text2im.model_creation import (
    create_model_and_diffusion,
    model_and_diffusion_defaults,
    model_and_diffusion_defaults_upsampler
)

# %%
# This notebook supports both CPU and GPU.
# On CPU, generating one sample may take on the order of 20 minutes.
# On a GPU, it should be under a minute.

has_cuda = th.cuda.is_available()
device = th.device('cpu' if not has_cuda else 'cuda')

# %%
# Create base model.
options = model_and_diffusion_defaults()
options['use_fp16'] = has_cuda
options['timestep_respacing'] = '100' # use 100 diffusion steps for fast sampling
model, diffusion = create_model_and_diffusion(**options)
model.eval()
if has_cuda:
    model.convert_to_fp16()
model.to(device)
model.load_state_dict(load_checkpoint('base', device))
print('total base parameters', sum(x.numel() for x in model.parameters()))
# Out:
# total base parameters 385030726

# %%
# Create upsampler model.
options_up = model_and_diffusion_defaults_upsampler()
options_up['use_fp16'] = has_cuda
options_up['timestep_respacing'] = 'fast27' # use 27 diffusion steps for very fast sampling
model_up, diffusion_up = create_model_and_diffusion(**options_up)
model_up.eval()
if has_cuda:
    model_up.convert_to_fp16()
model_up.to(device)
model_up.load_state_dict(load_checkpoint('upsample', device))
print('total upsampler parameters', sum(x.numel() for x in model_up.parameters()))
# Out:
# total upsampler parameters 398361286

# %%
def show_images(batch: th.Tensor):
    """ Display a batch of images inline. """
    scaled = ((batch + 1)*127.5).round().clamp(0,255).to(th.uint8).cpu()
    reshaped = scaled.permute(2, 0, 3, 1).reshape([batch.shape[2], -1, 3])
    display(Image.fromarray(reshaped.numpy()))

# %%
# Sampling parameters
prompt = "a cat reading a book"
batch_size = 4
guidance_scale = 0

# Tune this parameter to control the sharpness of 256x256 images.
# A value of 1.0 is sharper, but sometimes results in grainy artifacts.
upsample_temp = 0.997

# %%
##############################
# Sample from the base model #
##############################

# Create the text tokens to feed to the model.
tokens = model.tokenizer.encode(prompt)
tokens, mask = model.tokenizer.padded_tokens_and_mask(
    tokens, options['text_ctx']
)

# Create the classifier-free guidance tokens (empty)
full_batch_size = batch_size * 2
uncond_tokens, uncond_mask = model.tokenizer.padded_tokens_and_mask(
    [], options['text_ctx']
)

# Pack the tokens together into model kwargs.
model_kwargs = dict(
    tokens=th.tensor(
        [tokens] * batch_size + [uncond_tokens] * batch_size, device=device
    ),
    mask=th.tensor(
        [mask] * batch_size + [uncond_mask] * batch_size,
        dtype=th.bool,
        device=device,
    ),
)

# Create a classifier-free guidance sampling function
def model_fn(x_t, ts, **kwargs):
    half = x_t[: len(x_t) // 2]
    combined = th.cat([half, half], dim=0)
    model_out = model(combined, ts, **kwargs)
    eps, rest = model_out[:, :3], model_out[:, 3:]
    cond_eps, uncond_eps = th.split(eps, len(eps) // 2, dim=0)
    half_eps = uncond_eps + guidance_scale * (cond_eps - uncond_eps)
    eps = th.cat([half_eps, half_eps], dim=0)
    return th.cat([eps, rest], dim=1)

# Sample from the base model.
model.del_cache()
samples = diffusion.p_sample_loop(
    model_fn,
    (full_batch_size, 3, options["image_size"], options["image_size"]),
    device=device,
    clip_denoised=True,
    progress=True,
    model_kwargs=model_kwargs,
    cond_fn=None,
)[:batch_size]
model.del_cache()

# Show the output
show_images(samples)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=256x64>

# %%
##############################
# Upsample the 64x64 samples #
##############################

tokens = model_up.tokenizer.encode(prompt)
tokens, mask = model_up.tokenizer.padded_tokens_and_mask(
    tokens, options_up['text_ctx']
)

# Create the model conditioning dict.
model_kwargs = dict(
    # Low-res image to upsample.
    low_res=((samples+1)*127.5).round()/127.5 - 1,

    # Text tokens
    tokens=th.tensor(
        [tokens] * batch_size, device=device
    ),
    mask=th.tensor(
        [mask] * batch_size,
        dtype=th.bool,
        device=device,
    ),
)

# Sample from the base model.
model_up.del_cache()
up_shape = (batch_size, 3, options_up["image_size"], options_up["image_size"])
up_samples = diffusion_up.ddim_sample_loop(
    model_up,
    up_shape,
    noise=th.randn(up_shape, device=device) * upsample_temp,
    device=device,
    clip_denoised=True,
    progress=True,
    model_kwargs=model_kwargs,
    cond_fn=None,
)[:batch_size]
model_up.del_cache()

# Show the output
show_images(up_samples)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x256>
